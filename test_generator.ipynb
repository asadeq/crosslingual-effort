# %%
import pandas as pd
df = pd.read_csv('data.tsv', sep='\t', header=0)

# order by column "Recording"
df = df.sort_values(by='Recording')

#df.head(20)

# %%
# print total number of rows in data frame
print(len(df))

# %%
# print count
print(df['Recording'].value_counts())

# %%
# get summary statistics
#df.agg(["count", "min", "max", "median", "mean", "skew"])
